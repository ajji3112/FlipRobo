# %% [markdown]
# !pip install bs4
# !pip install requests

# %%
#importing libraries
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"cdc7275a-46c7-4aff-82d9-27f003915897","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRel
# ...

# %%
soup = BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
header= soup.find_all('span',class_="mw-headline")
header
# Out:
# [<span class="mw-headline" id="From_today's_featured_article">From today's featured article</span>,
#  <span class="mw-headline" id="Did_you_know_...">Did you know ...</span>,
#  <span class="mw-headline" id="In_the_news">In the news</span>,
#  <span class="mw-headline" id="On_this_day">On this day</span>,
#  <span class="mw-headline" id="From_today's_featured_list">From today's featured list</span>,
#  <span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span>,
#  <span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span>,
#  <span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span>,
#  <span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span>]

# %%
header_titles = []

for i in header:
    header_titles.append(i.text)

header_titles
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %%
page = requests.get("https://www.imdb.com/chart/moviemeter/?ref_=watch_tpks_chtmvm")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    \n    \n    \n\n    \n    \n    \n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>Most Popular Movies - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head
# ...

# %%
soup1 = BeautifulSoup(page.content,'html.parser')
soup1
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Most Popular Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
# ...

# %%
header_IMDB= soup1.find_all("td",class_="titleColumn")
header_IMDB
# Out:
# [<td class="titleColumn">
#  <a href="/title/tt12361974/" title="Zack Snyder (dir.), Henry Cavill, Ben Affleck">Zack Snyder's Justice League</a>
#  <span class="secondaryInfo">(2021)</span>
#  <div class="velocity">1
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  3)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt6802400/" title="Craig Brewer (dir.), Eddie Murphy, Arsenio Hall">Coming 2 America</a>
#  <span class="secondaryInfo">(2021)</span>
#  <div class="velocity">2
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  1)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0974015/" title="Zack Snyder (dir.), Ben Affleck, Gal Gadot">Justice League</a>
#  <span class="secondaryInfo">(2017)</span>
#  <div class="velocity">3
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  73)</span>
#  </div>
# ...

# %%
header_IMDB_name = []

for i in header_IMDB[:10]:
    b=i.find('a')
    header_IMDB_name.append(b.text.replace('\n',''))

header_IMDB_name
# Out:
# ["Zack Snyder's Justice League",
#  'Coming 2 America',
#  'Justice League',
#  'Cherry',
#  'Raya and the Last Dragon',
#  'Yes Day',
#  'Promising Young Woman',
#  'Nomadland',
#  'Mortal Kombat',
#  'Mank']

# %%
header_IMDB= soup1.find_all("td",class_="titleColumn")
header_IMDB
# Out:
# [<td class="titleColumn">
#  <a href="/title/tt12361974/" title="Zack Snyder (dir.), Henry Cavill, Ben Affleck">Zack Snyder's Justice League</a>
#  <span class="secondaryInfo">(2021)</span>
#  <div class="velocity">1
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  3)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt6802400/" title="Craig Brewer (dir.), Eddie Murphy, Arsenio Hall">Coming 2 America</a>
#  <span class="secondaryInfo">(2021)</span>
#  <div class="velocity">2
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  1)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0974015/" title="Zack Snyder (dir.), Ben Affleck, Gal Gadot">Justice League</a>
#  <span class="secondaryInfo">(2017)</span>
#  <div class="velocity">3
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  73)</span>
#  </div>
# ...

# %%
header_IMDB_year = []

for i in header_IMDB[:10]:
    b=i.find('span')
    header_IMDB_year.append(b.text.replace('\n',''))

header_IMDB_year
# Out:
# ['(2021)',
#  '(2021)',
#  '(2017)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2020)']

# %%
header_IMDB= soup1.find_all("td",class_="ratingColumn imdbRating")
header_IMDB
# Out:
# [<td class="ratingColumn imdbRating">
#  <strong title="8.3 based on 201,545 user ratings">8.3</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="5.4 based on 44,867 user ratings">5.4</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="6.2 based on 401,329 user ratings">6.2</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="6.6 based on 12,983 user ratings">6.6</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="7.5 based on 35,065 user ratings">7.5</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="5.7 based on 10,137 user ratings">5.7</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="7.5 based on 54,286 user ratings">7.5</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="7.6 based on 40,475 user ratings">7.6</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  </td>, <td class="ratingColumn imdbRating">
# ...

# %%
header_IMDB_rating1 = []
x= []
for i in header_IMDB[:10]:
    #b=i.find('td')
    header_IMDB_rating1.append(i.text.replace('\n','') + '\n'  )
    

header_IMDB_rating1
# Out:
# ['8.3\n',
#  '5.4\n',
#  '6.2\n',
#  '6.6\n',
#  '7.5\n',
#  '5.7\n',
#  '7.5\n',
#  '7.6\n',
#  '\n',
#  '7.0\n']

# %%
import pandas as pd

# %%
ds=pd.DataFrame(list(zip(header_IMDB_name,header_IMDB_year,header_IMDB_rating1)),columns=['Movie','Year','Rating'])

# %%
ds
# Out:
#                           Movie    Year Rating
# 0  Zack Snyder's Justice League  (2021)  8.3\n
# 1              Coming 2 America  (2021)  5.4\n
# 2                Justice League  (2017)  6.2\n
# 3                        Cherry  (2021)  6.6\n
# 4      Raya and the Last Dragon  (2021)  7.5\n
# 5                       Yes Day  (2021)  5.7\n
# 6         Promising Young Woman  (2020)  7.5\n
# 7                     Nomadland  (2020)  7.6\n
# 8                 Mortal Kombat  (2021)     \n
# 9                          Mank  (2020)  7.0\n

# %%
ds.to_csv('Scraping reviews.csv',index=False) #converting the dataframe to a csv file

# %%
page1 = requests.get("https://bookpage.com/reviews")
page1
# Out:
# <Response [200]>

# %%
page1.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Book Reviews | BookPage</title>\n<meta name="description" content="Book recommendations of the best new books by genre and more.">\n<meta name="keywords" content="book reviews, books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/reviews">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Book Reviews">\n<meta property="og:description" content="Book recommendations of the best new books by genre and more.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/reviews">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@bookpage">\n<meta name="twitter:creator" content="@bookpage">\n<meta name="robots" con
# ...

# %%
soup2 = BeautifulSoup(page1.content,'html.parser')
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <title>
#    Book Reviews | BookPage
#   </title>
#   <meta content="Book recommendations of the best new books by genre and more." name="description"/>
#   <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
#   <link href="https://bookpage.com/reviews" rel="canonical"/>
#   <meta content="BookPage.com" property="og:site_name"/>
#   <meta content="Book Reviews" property="og:title"/>
#   <meta content="Book recommendations of the best new books by genre and more." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://bookpage.com/reviews" property="og:url"/>
#   <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@bookpage" name="twitter:site"/>
# ...

# %%
header_book= soup2.find_all("h4",class_="italic")
header_book
# Out:
# [<h4 class="italic">
#  <a href="/reviews/26105-andrea-wang-watercress-childrens"> <span style="font-style:normal;">★ </span>Watercress</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26080-andrew-j-graff-raft-stars-fiction">Raft of Stars</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26119-kate-masur-until-justice-be-done-history">Until Justice Be Done</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26089-sarah-allen-breathing-underwater-childrens"> <span style="font-style:normal;">★ </span>Breathing Underwater</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/25969-tori-telfer-confident-women-nonfiction">Confident Women</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26085-constance-sayers-ladies-secret-circus-fiction">The Ladies of the Secret Circus</a>
#  </h4>, <h4 class="italic">
#  <a href="/reviews/26154-c-l-clark-unbroken-science-fiction-fantasy">The Unbroken</a>
#  </h4>, <h4 class="italic">
# ...

# %%
book_name = []

for i in header_book[0:4]:
    b=i.find('a')
    book_name.append(i.text.replace('\n','')+'\n' )
    

book_name
# Out:
# [' ★ Watercress\n',
#  'Raft of Stars\n',
#  'Until Justice Be Done\n',
#  ' ★ Breathing Underwater\n']

# %%
Author= soup2.find_all("p",class_="sans bold")
Author
# Out:
# [<p class="sans bold">
#  Andrea Wang, Jason Chin
#  </p>, <p class="sans bold">
#  Andrew J. Graff
#  </p>, <p class="sans bold">
#  Kate Masur
#  </p>, <p class="sans bold">
#  Sarah Allen
#  </p>, <p class="sans bold">
#  Tori Telfer
#  </p>, <p class="sans bold">
#  Constance Sayers
#  </p>, <p class="sans bold">
#  C.L. Clark
#  </p>, <p class="sans bold">
#  Craig Taylor
#  </p>, <p class="sans bold">
#  Alma Katsu
#  </p>, <p class="sans bold">
#  Cicely Tyson, Robin Miles
#  </p>]

# %%
Author1 = []

for i in Author[0:4]:
    b=i.find('p')
    Author1.append(i.text.replace('\n','')+'\n' )
    

Author1
# Out:
# ['Andrea Wang, Jason Chin\n',
#  'Andrew J. Graff\n',
#  'Kate Masur\n',
#  'Sarah Allen\n']

# %%
page3 = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/test")
page3
# Out:
# <Response [200]>

# %%
page3.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Test Match Team Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Test Match Team Rankings International Cricket Council"/>\n<meta property="og:image" content="htt
# ...

# %%
soup3 = BeautifulSoup(page3.content,'html.parser')
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Test Match Team Rankings International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Test Match Team Rankings International Cricket Council" property="og:title"/>
# ...

# %%
ODI_Team= soup3.find_all("span",class_="u-hide-phablet")
ODI_Team
# Out:
# [<span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="icn icn-facebook-circle u-hide-phablet"></span>,
#  <span class="icn icn-twitter-circle u-hide-phablet"></span>,
#  <span class="icn icn-instagram-circle u-hide-phablet"></span>,
#  <span class="icn icn-youtube-circle u-hide-phablet"></span>,
#  <span class="icn icn-tiktok-circle u-hide-phablet"></span>]

# %%
ODI1_Team = []

for i in ODI_Team[0:10]:
    b=i.find('span')
    ODI1_Team.append(i.text.replace('\span','') )
    

ODI1_Team
# Out:
# ['India',
#  'New Zealand',
#  'Australia',
#  'England',
#  'Pakistan',
#  'South Africa',
#  'Sri Lanka',
#  'West Indies',
#  'Bangladesh',
#  '']

# %%
ODI_Match= soup3.find_all("td",class_="table-body__cell u-center-text")
ODI_Match
# Out:
# [<td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,198</td>,
#  <td class="table-body__cell u-center-text">31</td>,
#  <td class="table-body__cell u-center-text">3,498</td>,
#  <td class="table-body__cell u-center-text">49</td>,
#  <td class="table-body__cell u-center-text">5,174</td>,
#  <td class="table-body__cell u-center-text">26</td>,
#  <td class="table-body__cell u-center-text">2,328</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">2,595</td>,
#  <td class="table-body__cell u-center-text">33</td>,
#  <td class="table-body__cell u-center-text">2,742</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">2,252</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">1,020</td>]

# %%
ODI_Match1 = []
i=0
for i in ODI_Match[0:10:2]:
    b=i.find('table-body__cell u-center-text')
    
    ODI_Match1.append(i.text )
    #Author1.append(i.text.replace('\n','')+'\n' )
    
    

ODI_Match1
# Out:
# ['27', '31', '49', '26', '29']

# %%
page4 = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/test")
page4
# Out:
# <Response [200]>

# %%
page4.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Test Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Test Match Player Rankings International Cricket Council"/>\n<meta property="og:image" cont
# ...

# %%
soup4 = BeautifulSoup(page4.content,'html.parser')
print(soup4.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Test Match Player Rankings International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Test Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
#ODI_Ranking= soup4.find_all("div",class_="rankings-block__banner--name")
ODI_Ranking= soup4.find_all("td",class_="table-body__cell name")
ODI_Ranking
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/271">Steve Smith</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/4029">Marnus Labuschagne</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/887">Joe Root</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/164">Virat Kohli</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/2759">Babar Azam</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/2972">Rishabh Pant</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/2890">Henry Nicholls</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
# ...

# %%
ODI_Ranking1 = []

for i in ODI_Ranking[0:10]:
    b=i.find('table-body__cell name')
    ODI_Ranking1.append(i.text.replace('\n',' ') )
    #Author1.append(i.text.replace('\n','')+'\n' )
    
  

ODI_Ranking1
# Out:
# [' Steve Smith ',
#  ' Marnus Labuschagne ',
#  ' Joe Root ',
#  ' Virat Kohli ',
#  ' Babar Azam ',
#  ' Rishabh Pant ',
#  ' Henry Nicholls ',
#  ' Rohit Sharma ',
#  ' David Warner ',
#  ' Ravichandran Ashwin ']

# %%
page4 = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page4
# Out:
# <Response [200]>

# %%
soup5 = BeautifulSoup(page4.content,'html.parser')
print(soup5.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
ODI_Womens_Team= soup5.find_all("span",class_="u-hide-phablet")
ODI_Womens_Team
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="icn icn-facebook-circle u-hide-phablet"></span>,
#  <span class="icn icn-twitter-circle u-hide-phablet"></span>,
#  <span class="icn icn-instagram-circle u-hide-phablet"></span>,
#  <span class="icn icn-youtube-circle u-hide-phablet"></span>,
#  <span class="icn icn-tiktok-circle u-hide-phablet"></span>]

# %%
ODI_Womens_Team1 = []

for i in ODI_Womens_Team[0:10]:
    b=i.find('span')
    ODI_Womens_Team1.append(i.text.replace('\span','') )
    

ODI_Womens_Team1
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %%
ODI1_Womens_Team= soup5.find_all("td",class_="table-body__cell u-center-text")
ODI1_Womens_Team
# Out:
# [<td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,828</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,993</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,226</td>,
#  <td class="table-body__cell u-center-text">18</td>,
#  <td class="table-body__cell u-center-text">1,696</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,101</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
#  <td class="table-body__cell u-center-text">2</td>,
# ...

# %%
ODI1_Womens_Team1 = []
i=0
for i in ODI1_Womens_Team[0:10:2]:
    b=i.find('td')
    ODI1_Womens_Team1.append(i.text)
    

ODI1_Womens_Team1
# Out:
# ['24', '17', '20', '18', '12']

# %%
ODI1_Womens_Team1 = []
i=0
for i in ODI1_Womens_Team[1:10:2]:
    b=i.find('td')
    ODI1_Womens_Team1.append(i.text)
    

ODI1_Womens_Team1
# Out:
# ['2,828', '1,993', '2,226', '1,696', '1,025']

# %%
page6 = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")
page6
# Out:
# <Response [200]>

# %%
soup6 = BeautifulSoup(page6.content,'html.parser')
print(soup6.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
ODI_Womens_Player= soup6.find_all("td",class_="table-body__cell name")
ODI_Womens_Player
# Out:
# [<td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1785">Lizelle Lee</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/558">Mithali Raj</a>
#  </td>, <td class="table-body__cell name">
#  <a href="/rankings/womens/player-rankings/471">Ellyse Perry</a>
#  </td>, <td class="table-body__cell name">
# ...

# %%
ODI1_Womens_Player1 = []
i=0
for i in ODI_Womens_Player[0:10]:
    b=i.find('td')
    ODI1_Womens_Player1.append(i.text.replace('\n',''))
    

ODI1_Womens_Player1
# Out:
# ['Lizelle Lee',
#  'Meg Lanning',
#  'Stafanie Taylor',
#  'Alyssa Healy',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Ellyse Perry',
#  'Natalie Sciver',
#  'Marizanne Kapp']

# %%
ODI_Womens_Team= soup6.find_all("span",class_="table-body__logo-text")
ODI_Womens_Team
# Out:
# [<span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">SA</span>,
# ...

# %%
ODI1_Womens_Team1 = []
i=0
for i in ODI_Womens_Team[0:10]:
    b=i.find('span')
    ODI1_Womens_Team1.append(i.text.replace('\n',''))
    

ODI1_Womens_Team1
# Out:
# ['SA', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'IND', 'AUS', 'ENG', 'SA']

# %%
ODI_Womens_Rating= soup6.find_all("td",class_="table-body__cell u-text-right rating")
ODI_Womens_Rating
# Out:
# [<td class="table-body__cell u-text-right rating">758</td>,
#  <td class="table-body__cell u-text-right rating">749</td>,
#  <td class="table-body__cell u-text-right rating">746</td>,
#  <td class="table-body__cell u-text-right rating">741</td>,
#  <td class="table-body__cell u-text-right rating">740</td>,
#  <td class="table-body__cell u-text-right rating">710</td>,
#  <td class="table-body__cell u-text-right rating">709</td>,
#  <td class="table-body__cell u-text-right rating">691</td>,
#  <td class="table-body__cell u-text-right rating">685</td>,
#  <td class="table-body__cell u-text-right rating">747</td>,
#  <td class="table-body__cell u-text-right rating">735</td>,
#  <td class="table-body__cell u-text-right rating">717</td>,
#  <td class="table-body__cell u-text-right rating">681</td>,
#  <td class="table-body__cell u-text-right rating">666</td>,
#  <td class="table-body__cell u-text-right rating">655</td>,
#  <td class="table-body__cell u-text-right rating">641</td>,
# ...

# %%
ODI_Womens_Rating1 = []
i=0
for i in ODI_Womens_Rating[0:10]:
    b=i.find('td')
    ODI_Womens_Rating1.append(i.text.replace('\n',''))
    

ODI_Womens_Rating1
# Out:
# ['758', '749', '746', '741', '740', '710', '709', '691', '685', '747']

# %%
amazon = requests.get("https://www.amazon.in/s?k=mobile+phone&rh=n%3A976419031%2Cp_36%3A1318506031&dc&qid=1616768894&rnid=1318502031&ref=sr_nr_p_36_4")
amazon
# Out:
# <Response [503]>

# %%
soup7 = BeautifulSoup(amazon.content,'html.parser')
print(soup7.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title dir="ltr">
#    Amazon.in
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
#   <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
product_name= soup7.find_all("span",class_="a-size-base-plus a-color-base a-text-normal")

product_name
# Out:
# []

# %%
product_name1 = []
i=0
for i in product_name:
    b=i.find('span')
    product_name1.append(i.text)
    

product_name1
# Out:
# []

# %%
product_rating= soup7.find_all("i",class_="a-icon a-icon-star-small a-star-small-4 aok-align-bottom")

product_rating
# Out:
# []

# %%
product_rating1 = []
i=0
for i in product_rating:
    b=i.find('i')
    product_rating1.append(i.text)
    

product_rating1
# Out:
# []

# %%
product_price= soup7.find_all("span",class_="a-price-whole")

product_price
# Out:
# []

# %%
product_price1 = []
i=0
for i in product_price:
    b=i.find('i')
    product_price1.append(i.text)
    

product_price1
# Out:
# []

# %%
image_link= soup7.find_all("img")

image_link
# Out:
# [<img src="https://images-na.ssl-images-amazon.com/captcha/lqbiackd/Captcha_gvkfywvzlf.jpg"/>,
#  <img src="https://fls-eu.amazon.in/1/oc-csi/1/OP/requestId=FRPA1XC3ZD8F6TNE01AK&amp;js=0">
#  </img>]

# %%
image_link1 = []
i=0
for i in image_link:
    b=i.attrs['src']
    image_link1.append(b)
    

image_link1
# Out:
# ['https://images-na.ssl-images-amazon.com/captcha/lqbiackd/Captcha_gvkfywvzlf.jpg',
#  'https://fls-eu.amazon.in/1/oc-csi/1/OP/requestId=FRPA1XC3ZD8F6TNE01AK&js=0']

# %%
weather = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YF3s368zbIU")
weather
# Out:
# <Response [200]>

# %%
soup8 = BeautifulSoup(weather.content,'html.parser')
print(soup8.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <!-- Meta -->
#   <meta content="width=device-width" name="viewport"/>
#   <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/>
#   <title>
#    National Weather Service
#   </title>
#   <meta content="National Weather Service" name="DC.title">
#    <meta content="NOAA National Weather Service National Weather Service" name="DC.description"/>
#    <meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/>
#    <meta content="" name="DC.date.created" scheme="ISO8601"/>
#    <meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/>
#    <meta content="weather, National Weather Service" name="DC.keywords"/>
#    <meta content="NOAA's National Weather Service" name="DC.publisher"/>
#    <meta content="National Weather Service" name="DC.contributor"/>
#    <meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/>
#    <meta content="General" name="rating"/>
# ...

# %%
weather_period= soup8.find_all("p",class_="period-name")

weather_period
# Out:
# [<p class="period-name">Today<br/><br/></p>,
#  <p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>,
#  <p class="period-name">Monday<br/><br/></p>,
#  <p class="period-name">Monday<br/>Night</p>,
#  <p class="period-name">Tuesday<br/><br/></p>]

# %%
weather_period1 = []
i=0
for i in weather_period:
    b=i.find('p')
    weather_period1.append(i.text.replace('\n',''))
    

weather_period1
# Out:
# ['Today',
#  'Tonight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'Monday',
#  'MondayNight',
#  'Tuesday']

# %%
weather_desc= soup8.find_all("p",class_="short-desc")

weather_desc
# Out:
# [<p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Clear</p>,
#  <p class="short-desc">Sunny</p>]

# %%
weather_desc1 = []
i=0
for i in weather_desc:
    b=i.find('p')
    weather_desc1.append(i.text.replace('\n',''))
    

weather_desc1
# Out:
# ['Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Clear',
#  'Sunny']

# %%
weather_temp= soup8.find_all("p",class_="temp temp-high")

weather_temp
# Out:
# [<p class="temp temp-high">High: 72 °F</p>,
#  <p class="temp temp-high">High: 74 °F</p>,
#  <p class="temp temp-high">High: 71 °F</p>,
#  <p class="temp temp-high">High: 65 °F</p>,
#  <p class="temp temp-high">High: 71 °F</p>]

# %%
weather_temp1 = []
i=0
for i in weather_desc:
    b=i.find('p')
    weather_desc1.append(i.text.replace('\n',''))
    

weather_desc1
# Out:
# ['Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Clear',
#  'Sunny',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Clear',
#  'Sunny']
